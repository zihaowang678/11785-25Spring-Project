# %% [markdown]
# <a href="https://colab.research.google.com/github/zihaowang678/11785-25Spring-Project/blob/main/evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
drive.mount('/content/drive')
DATA_DIR = "/content/drive/My Drive/DL Proj/data/"
## process your model_result
metrics_result = pd.read_csv(DATA_DIR + "metrics.csv")[["transcriptid","label"]]
model_result = pd.read_csv(DATA_DIR + "gpt_4o_result.csv").rename(columns={"transcript_id":"transcriptid"})
model_result["sentiment"] = model_result["sentiment"].map({"neutral":0, "positive":1, "negative":-1})
## your model_result should have two columns "transcriptid" and "sentiment". for sentiment, it should only have 1,0,-1
model_result = pd.merge(model_result, metrics_result, on="transcriptid")
print("acc: ", accuracy_score(model_result["sentiment"], model_result["label"]))
print("precision: ", precision_score(model_result["sentiment"], model_result["label"], average= "weighted"))
print("recall: ", recall_score(model_result["sentiment"], model_result["label"], average= "weighted"))
print("f1: ", f1_score(model_result["sentiment"], model_result["label"], average= "weighted"))
# print("confusion matrix: \n", confusion_matrix(model_result["sentiment"], model_result["label"]))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# acc:  0.3361
# precision:  0.5479604044366644
# recall:  0.3361
# f1:  0.37342849793125477

# %%
import os
DATA_DIR = "/content/drive/MyDrive/11785 Coursework/DL Proj/data/"
os.listdir(DATA_DIR)

metrics_result = pd.read_csv(DATA_DIR + "metrics.csv")[["transcriptid","label"]]

# %%
metrics_result
# Out:
#         transcriptid  label
# 0              504.0      0
# 1            18033.0      0
# 2            18034.0      0
# 3            18035.0     -1
# 4          2469510.0     -1
# ...              ...    ...
# 128738     3302971.0     -1
# 128739     3303142.0     -1
# 128740     3303156.0     -1
# 128741     3305110.0     -1
# 128742     3349905.0     -1
#
# [128743 rows x 2 columns]

# %%
model_result = pd.read_csv(DATA_DIR + "gpt_4o_result.csv").rename(columns={"transcript_id":"transcriptid"})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-f86f90ae8a85> in <cell line: 0>()
# ----> 1 metrics_result = pd.read_csv(DATA_DIR + "metrics.csv")[["transcriptid","label"]]
#       2 # model_result = pd.read_csv(DATA_DIR + "gpt_4o_result.csv").rename(columns={"transcript_id":"transcriptid"})
#
# ...
